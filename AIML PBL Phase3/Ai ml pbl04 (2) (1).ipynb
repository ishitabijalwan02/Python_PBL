# %%
#Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load dataset
df = pd.read_csv("agri_dataset.csv")

# Display dataset
df
# Out:
#       Region  Rainfall_mm  Temperature_C  Soil_Moisture_pct   Soil_pH  \
# 0          0      1526.00      33.990743          41.632277  6.887571
# 1          1      1260.00      34.502654          41.040131  6.588822
# 2          2      1694.00      21.728100          38.687630  5.637348
# 3          3      1530.00      22.713835          62.786184  7.044777
# 4          4      1495.00      30.675171          72.400794       NaN
# ...      ...          ...            ...                ...       ...
# 1045    1045       560.00      32.482067          51.444344  7.758383
# 1046    1046      8626.75      24.833490                NaN  6.594082
# 1047    1047          NaN      21.233451          65.878606  5.976657
# 1048    1048       980.00      23.173767                NaN  6.146388
# 1049    1049       923.00      31.428493                NaN  6.298243
#
#        Nitrogen  Phosphorus  Potassium  Irrigation_pct  Crop_Area_ha  ...  \
# ...

# %%
# Structure of dataset
df.info()

# Statistical summary
df.describe()

# Missing values count
df.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Region                1050 non-null   int64
#  1   Rainfall_mm           951 non-null    float64
#  2   Temperature_C         903 non-null    float64
#  3   Soil_Moisture_pct     901 non-null    float64
#  4   Soil_pH               955 non-null    float64
#  5   Nitrogen              904 non-null    float64
#  6   Phosphorus            950 non-null    float64
#  7   Potassium             896 non-null    float64
#  8   Irrigation_pct        950 non-null    float64
#  9   Crop_Area_ha          946 non-null    float64
#  10  Fertilizer_kg_per_ha  949 non-null    float64
#  11  Pesticide_kg_per_ha   954 non-null    float64
#  12  Sunlight_hours        946 non-null    float64
#  13  Humidity_pct          898 non-null    float64
#  14  Altitude_m            952 non-null    float64
# ...

# %%
# Drop 'region' column
df.drop(columns=['Region'], inplace=True)

df
# Out:
#       Rainfall_mm  Temperature_C  Soil_Moisture_pct   Soil_pH   Nitrogen  \
# 0         1526.00      33.990743          41.632277  6.887571  58.405306
# 1         1260.00      34.502654          41.040131  6.588822  40.918000
# 2         1694.00      21.728100          38.687630  5.637348  43.657011
# 3         1530.00      22.713835          62.786184  7.044777        NaN
# 4         1495.00      30.675171          72.400794       NaN  66.529307
# ...           ...            ...                ...       ...        ...
# 1045       560.00      32.482067          51.444344  7.758383  43.862350
# 1046      8626.75      24.833490                NaN  6.594082  38.708501
# 1047          NaN      21.233451          65.878606  5.976657        NaN
# 1048       980.00      23.173767                NaN  6.146388  49.201895
# 1049       923.00      31.428493                NaN  6.298243  35.505189
#
#       Phosphorus  Potassium  Irrigation_pct  Crop_Area_ha  \
# ...

# %%
df.columns
# Out:
# Index(['Rainfall_mm', 'Temperature_C', 'Soil_Moisture_pct', 'Soil_pH',
#        'Nitrogen', 'Phosphorus', 'Potassium', 'Irrigation_pct', 'Crop_Area_ha',
#        'Fertilizer_kg_per_ha', 'Pesticide_kg_per_ha', 'Sunlight_hours',
#        'Humidity_pct', 'Altitude_m', 'Wind_kmh', 'Groundwater_m',
#        'Crop_Diversity_Index', 'Mechanization_Score', 'Yield_Variance',
#        'Avg_Yield_ton_per_ha'],
#       dtype='str')

# %%
# Handle missing values 

df['Rainfall_mm'] = df['Rainfall_mm'].fillna(df['Rainfall_mm'].mean())
df['Temperature_C'] = df['Temperature_C'].fillna(df['Temperature_C'].mean())
df['Soil_Moisture_pct'] = df['Soil_Moisture_pct'].fillna(df['Soil_Moisture_pct'].mean())
df['Soil_pH'] = df['Soil_pH'].fillna(df['Soil_pH'].median())

df['Nitrogen'] = df['Nitrogen'].fillna(df['Nitrogen'].mean())
df['Phosphorus'] = df['Phosphorus'].fillna(df['Phosphorus'].mean())
df['Potassium'] = df['Potassium'].fillna(df['Potassium'].mean())

df['Irrigation_pct'] = df['Irrigation_pct'].fillna(df['Irrigation_pct'].mean())
df['Crop_Area_ha'] = df['Crop_Area_ha'].fillna(df['Crop_Area_ha'].mean())

df['Fertilizer_kg_per_ha'] = df['Fertilizer_kg_per_ha'].fillna(df['Fertilizer_kg_per_ha'].mean())
df['Pesticide_kg_per_ha'] = df['Pesticide_kg_per_ha'].fillna(df['Pesticide_kg_per_ha'].mean())

df['Sunlight_hours'] = df['Sunlight_hours'].fillna(df['Sunlight_hours'].mean())
df['Humidity_pct'] = df['Humidity_pct'].fillna(df['Humidity_pct'].mean())

df['Altitude_m'] = df['Altitude_m'].fillna(df['Altitude_m'].mean())
df['Wind_kmh'] = df['Wind_kmh'].fillna(df['Wind_kmh'].mean())
df['Groundwater_m'] = df['Groundwater_m'].fillna(df['Groundwater_m'].mean())

df['Crop_Diversity_Index'] = df['Crop_Diversity_Index'].fillna(df['Crop_Diversity_Index'].mean())
df['Mechanization_Score'] = df['Mechanization_Score'].fillna(df['Mechanization_Score'].mean())
df['Yield_Variance'] = df['Yield_Variance'].fillna(df['Yield_Variance'].mean())

df['Avg_Yield_ton_per_ha'] = df['Avg_Yield_ton_per_ha'].fillna(df['Avg_Yield_ton_per_ha'].mean())

df
# Out:
#       Rainfall_mm  Temperature_C  Soil_Moisture_pct   Soil_pH   Nitrogen  \
# 0     1526.000000      33.990743          41.632277  6.887571  58.405306
# 1     1260.000000      34.502654          41.040131  6.588822  40.918000
# 2     1694.000000      21.728100          38.687630  5.637348  43.657011
# 3     1530.000000      22.713835          62.786184  7.044777  -3.006637
# 4     1495.000000      30.675171          72.400794  6.716066  66.529307
# ...           ...            ...                ...       ...        ...
# 1045   560.000000      32.482067          51.444344  7.758383  43.862350
# 1046  8626.750000      24.833490           6.613539  6.594082  38.708501
# 1047  1197.092271      21.233451          65.878606  5.976657  -3.006637
# 1048   980.000000      23.173767           6.613539  6.146388  49.201895
# 1049   923.000000      31.428493           6.613539  6.298243  35.505189
#
#       Phosphorus  Potassium  Irrigation_pct  Crop_Area_ha  \
# ...

# %%
# Remove duplicate rows

df.drop_duplicates(inplace=True)

df
# Out:
#       Rainfall_mm  Temperature_C  Soil_Moisture_pct   Soil_pH   Nitrogen  \
# 0     1526.000000      33.990743          41.632277  6.887571  58.405306
# 1     1260.000000      34.502654          41.040131  6.588822  40.918000
# 2     1694.000000      21.728100          38.687630  5.637348  43.657011
# 3     1530.000000      22.713835          62.786184  7.044777  -3.006637
# 4     1495.000000      30.675171          72.400794  6.716066  66.529307
# ...           ...            ...                ...       ...        ...
# 1045   560.000000      32.482067          51.444344  7.758383  43.862350
# 1046  8626.750000      24.833490           6.613539  6.594082  38.708501
# 1047  1197.092271      21.233451          65.878606  5.976657  -3.006637
# 1048   980.000000      23.173767           6.613539  6.146388  49.201895
# 1049   923.000000      31.428493           6.613539  6.298243  35.505189
#
#       Phosphorus  Potassium  Irrigation_pct  Crop_Area_ha  \
# ...

# %%
# Removing outliers from Rainfall

Q1 = df['Rainfall_mm'].quantile(0.25)
Q3 = df['Rainfall_mm'].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

df = df[(df['Rainfall_mm'] >= lower) & (df['Rainfall_mm'] <= upper)]

# %%
# Removing outliers from Temperature

Q1 = df['Temperature_C'].quantile(0.25)
Q3 = df['Temperature_C'].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

df = df[(df['Temperature_C'] >= lower) & (df['Temperature_C'] <= upper)]

# %%
# Removing outliers from Soil Moisture

Q1 = df['Soil_Moisture_pct'].quantile(0.25)
Q3 = df['Soil_Moisture_pct'].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

df = df[(df['Soil_Moisture_pct'] >= lower) & (df['Soil_Moisture_pct'] <= upper)]

# %%
df
# Out:
#       Rainfall_mm  Temperature_C  Soil_Moisture_pct   Soil_pH   Nitrogen  \
# 0     1526.000000      33.990743          41.632277  6.887571  58.405306
# 1     1260.000000      34.502654          41.040131  6.588822  40.918000
# 2     1694.000000      21.728100          38.687630  5.637348  43.657011
# 3     1530.000000      22.713835          62.786184  7.044777  -3.006637
# 4     1495.000000      30.675171          72.400794  6.716066  66.529307
# ...           ...            ...                ...       ...        ...
# 1044  1706.000000      27.102874           6.613539  6.716066  56.255434
# 1045   560.000000      32.482067          51.444344  7.758383  43.862350
# 1047  1197.092271      21.233451          65.878606  5.976657  -3.006637
# 1048   980.000000      23.173767           6.613539  6.146388  49.201895
# 1049   923.000000      31.428493           6.613539  6.298243  35.505189
#
#       Phosphorus  Potassium  Irrigation_pct  Crop_Area_ha  \
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
cols = ['Rainfall_mm','Temperature_C','Soil_Moisture_pct','Soil_pH',
        'Nitrogen','Phosphorus','Potassium','Irrigation_pct',
        'Crop_Area_ha','Fertilizer_kg_per_ha','Pesticide_kg_per_ha',
        'Sunlight_hours','Humidity_pct','Altitude_m','Wind_kmh',
        'Groundwater_m','Crop_Diversity_Index','Mechanization_Score',
        'Yield_Variance','Avg_Yield_ton_per_ha']

scaler = StandardScaler()
df[cols] = scaler.fit_transform(df[cols])

# %%
df
# Out:
#       Rainfall_mm  Temperature_C  Soil_Moisture_pct   Soil_pH  Nitrogen  \
# 0        1.001176       0.993364          -0.286840  0.098214  0.121805
# 1        0.315950       1.084380          -0.314196  0.097605  0.087276
# 2        1.433950      -1.186879          -0.422875  0.095666  0.092684
# 3        1.011480      -1.011620           0.690417  0.098534  0.000548
# 4        0.921319       0.403870           1.134588  0.097864  0.137845
# ...           ...            ...                ...       ...       ...
# 1044     1.464862      -0.231268          -1.904617  0.097864  0.117560
# 1045    -1.487275       0.725128           0.166453  0.099988  0.093090
# 1047     0.153898      -1.274825           0.833279  0.096358  0.000548
# 1048    -0.405340      -0.929846          -1.904617  0.096703  0.103633
# 1049    -0.552174       0.537808          -1.904617  0.097013  0.076589
#
#       Phosphorus  Potassium  Irrigation_pct  Crop_Area_ha  \
# ...

# %%
# Converting all values to positive

df = df.abs()

df
# Out:
#       Rainfall_mm  Temperature_C  Soil_Moisture_pct   Soil_pH  Nitrogen  \
# 0        1.001176       0.993364           0.286840  0.098214  0.121805
# 1        0.315950       1.084380           0.314196  0.097605  0.087276
# 2        1.433950       1.186879           0.422875  0.095666  0.092684
# 3        1.011480       1.011620           0.690417  0.098534  0.000548
# 4        0.921319       0.403870           1.134588  0.097864  0.137845
# ...           ...            ...                ...       ...       ...
# 1044     1.464862       0.231268           1.904617  0.097864  0.117560
# 1045     1.487275       0.725128           0.166453  0.099988  0.093090
# 1047     0.153898       1.274825           0.833279  0.096358  0.000548
# 1048     0.405340       0.929846           1.904617  0.096703  0.103633
# 1049     0.552174       0.537808           1.904617  0.097013  0.076589
#
#       Phosphorus  Potassium  Irrigation_pct  Crop_Area_ha  \
# ...

# %%
# Histogram of Yield

plt.hist(df['Avg_Yield_ton_per_ha'], edgecolor='black')
plt.title('Histogram of Yield')
plt.xlabel('Yield')
plt.ylabel('Frequency')
plt.show()

# %%
# Boxplot of Rainfall

plt.boxplot(df['Rainfall_mm'])
plt.title('Boxplot of Rainfall')
plt.ylabel('Rainfall')
plt.show()

# %%
# Scatter plot between Rainfall and Yield

plt.scatter(df['Rainfall_mm'], df['Avg_Yield_ton_per_ha'], edgecolors='black')
plt.title('Rainfall vs Yield')
plt.xlabel('Rainfall')
plt.ylabel('Yield')
plt.show()

# %%
# Line plot of Temperature

plt.plot(df['Temperature_C'])
plt.title('Temperature Trend')
plt.xlabel('Index')
plt.ylabel('Temperature')
plt.show()

# %%
X = df[['Rainfall_mm','Temperature_C','Soil_Moisture_pct','Avg_Yield_ton_per_ha']]

X
# Out:
#       Rainfall_mm  Temperature_C  Soil_Moisture_pct  Avg_Yield_ton_per_ha
# 0        1.001176       0.993364           0.286840              0.121907
# 1        0.315950       1.084380           0.314196              0.121383
# 2        1.433950       1.186879           0.422875              0.122727
# 3        1.011480       1.011620           0.690417              0.120656
# 4        0.921319       0.403870           1.134588              0.119834
# ...           ...            ...                ...                   ...
# 1044     1.464862       0.231268           1.904617              0.120744
# 1045     1.487275       0.725128           0.166453              0.024553
# 1047     0.153898       1.274825           0.833279              0.024553
# 1048     0.405340       0.929846           1.904617              0.121833
# 1049     0.552174       0.537808           1.904617              0.121262
#
# [823 rows x 4 columns]

# %%
from sklearn.cluster import KMeans

wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

# Plot elbow curve
plt.plot(range(1,11), wcss, marker='o')
plt.title('Elbow Method (Reduced Features)')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

for k in range(2,10):
    km = KMeans(n_clusters=k, random_state=42, n_init=20)
    labels = km.fit_predict(X_scaled)
    score = silhouette_score(X_scaled, labels)
    print(k, score)
# Out:
# 2 0.6311579047980839
# 3 0.6146671903572108
# 4 0.5069811359893981
# 5 0.6068709818135584
# 6 0.6041791837912944
# 7 0.5437150125984301
# 8 0.24051464450506746
# 9 0.645493368413919

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=0.95)
X_pca = pca.fit_transform(X_scaled)

# %%
plt.scatter(df['Rainfall_mm'], df['Avg_Yield_ton_per_ha'],
            c=df['Cluster'], cmap='viridis')

plt.title('Clusters')
plt.xlabel('Rainfall')
plt.ylabel('Yield')

plt.show()

# %%
df['Cluster'].value_counts()
# Out:
# Cluster
# 0    447
# 2    366
# 1     10
# Name: count, dtype: int64

# %%
corr_matrix = df.corr()
corr_matrix
# Out:
#                       Rainfall_mm  Temperature_C  Soil_Moisture_pct   Soil_pH  \
# Rainfall_mm              1.000000       0.014876           0.048218  0.098031
# Temperature_C            0.014876       1.000000          -0.009973 -0.027200
# Soil_Moisture_pct        0.048218      -0.009973           1.000000  0.055160
# Soil_pH                  0.098031      -0.027200           0.055160  1.000000
# Nitrogen                -0.033000       0.021111          -0.068345 -0.009350
# Phosphorus               0.014596      -0.055087           0.002539 -0.011658
# Potassium                0.016066      -0.023976          -0.031328 -0.008811
# Irrigation_pct          -0.024945       0.024814           0.031666 -0.011166
# Crop_Area_ha            -0.010548      -0.050037           0.040221 -0.012785
# Fertilizer_kg_per_ha    -0.001994       0.006603          -0.003738 -0.015084
# Pesticide_kg_per_ha     -0.010966      -0.037614           0.012438 -0.008909
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
upper = corr_matrix.where(
    np.triu(np.ones(corr_matrix.shape), k=1).astype(bool)
)

to_drop = [col for col in upper.columns if any(upper[col] > 0.85)]

to_drop
# Out:
# ['Cluster']

# %%
# Dropping selected features

cols_to_drop = [col for col in to_drop if col in df.columns]

df.drop(columns=cols_to_drop, inplace=True)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Features (exclude cluster column if present)
X = df.drop(columns=['Cluster'], errors='ignore')

# Scale data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# PCA
pca = PCA(n_components=2)   # reduce to 2 components
X_pca = pca.fit_transform(X_scaled)

print("Explained Variance Ratio:")
print(pca.explained_variance_ratio_)
# Out:
# Explained Variance Ratio:
# [0.06304259 0.06260346]

# %%
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score

# Apply PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Silhouette score using PCA data
score = silhouette_score(X_pca, kmeans.labels_)

print(score)
# Out:
# 0.17407972373039887

# %%
kmeans.fit(X_pca)
score = silhouette_score(X_pca, kmeans.labels_)
print(score)
# Out:
# 0.8106383131627275

# %%
import pickle

# Save KMeans model
with open('kmeans_model.pkl','wb') as file:
    pickle.dump(kmeans,file)

# Save scaler
with open('scaler.pkl','wb') as file:
    pickle.dump(scaler,file)

# Save PCA (if used)
with open('pca.pkl','wb') as file:
    pickle.dump(pca,file)

# %%
import pickle

with open('kmeans_model.pkl','rb') as file:
    model = pickle.load(file)

with open('scaler.pkl','rb') as file:
    scaler = pickle.load(file)

with open('pca.pkl','rb') as file:
    pca = pickle.load(file)

# %%
new_data = new_data = [[
800,
25,
60,
6.8,
120,
45,
90,
70,
500,
180,
5,
8,
65,
400,
12,
15,
0.72,
78,
1.5,
4.2
]]   # 20 features

scaled = scaler.transform(new_data)
new_pca = pca.transform(scaled)

cluster = model.predict(new_pca)

print(cluster)
# Out:
# [2]
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
import pickle

# Save trained KMeans model
with open('kmeans_model.pkl', 'wb') as file:
    pickle.dump(kmeans, file)

# Save scaler
with open('scaler.pkl', 'wb') as file:
    pickle.dump(scaler, file)

# Save PCA model (if used)
with open('pca.pkl', 'wb') as file:
    pickle.dump(pca, file)

print("Models saved successfully")
# Out:
# Models saved successfully
